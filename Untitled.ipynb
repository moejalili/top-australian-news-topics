# %% [markdown]
# #  Case Study : News

# %% [markdown]
# ### Categorization
# - National
# - International
# - Sports
# - Media
# - Travel & Lifestyle
# - Stock Market
# - Politics
# - Finance

# %% [markdown]
# web are rapidly growing in the era of information age where each new site hase its own different layout and categorization for grouping news
# - these heterogeneity of layout and categorization cannot always satisfy individual users need so remove these heterogeneity and classifying the news articles according to the user preference is a formidable task companies use web crawler to extract useful text from HTML pages , the news articles
# - we remove the less significant words which are the stop words from the document or articles and then we apply the name by his classifier for calssifying news contents based on the news code

# %% [markdown]
# # 1. Case Study
#
# - Question: What were the top Australian news topics over the last decade,
# - what can these say about the national conversation?

# %% [markdown]
# https://www.youtube.com/watch?v=l3dZ6ZNFjo0

# %% [markdown]
# # Methodology ??

# %% [markdown]
# # 2. Collect / Load Data

# %%
file_path = "abcnews-date-text.csv"

# load the .csv dataset
news = pd.read_csv(file_path)

# take a look at the dataset
news
# Out:
#          publish_date                                      headline_text
# 0            20030219  aba decides against community broadcasting lic...
# 1            20030219     act fire witnesses must be aware of defamation
# 2            20030219     a g calls for infrastructure protection summit
# 3            20030219           air nz staff in aust strike for pay rise
# 4            20030219      air nz strike to affect australian travellers
# ...               ...                                                ...
# 1186013      20191231  vision of flames approaching corryong in victoria
# 1186014      20191231  wa police and government backflip on drug amne...
# 1186015      20191231  we have fears for their safety: victorian premier
# 1186016      20191231                              when do the 20s start
# 1186017      20191231  yarraville shooting woman dead man critically ...
#
# [1186018 rows x 2 columns]

# %%
# the dimensions of dataset
dimensions = news.shape

print( 'General size of the dataset: ' + str( dimensions ))

# extract the number of rows and columns
num_rows = dimensions[0]
num_col  = dimensions[1]
print('The dataset has ' + str( num_rows ) + ' rows and ' + str( num_col ) + ' columns!' )
# Out:
# General size of the dataset: (1186018, 2)
# The dataset has 1186018 rows and 2 columns!

# %% [markdown]
# **QUESTION:**
# - Q1: What do the **rows** and **columns** of this dataset **represent**?
# - Q2: What is this dataset about?
# - Q3: What are the main problems with this dataset?
# - Q4: Is the data relevant to our initial question (our Business concern)?

# %% [markdown]
# **Answer:**
#
# Q1:
# -  In **columns**, we have publish_date and heading_text.
#             - publish_date represent date of publishing for the article in yyyyMMdd format
#             - heading text represent text of the headline in Ascii , English , lowercase, which is unstructured in nature
# - In **rows**, we have date of publishing the article and the text of article
#
#
# Q2: The dataset includes all of articles from ABC news website from early-2003 to last date of 2019 with focus on Australia.
#
# Q3: Dataset containts unstructured data which needs to be structured for a better analysis.
#
# Q4: Yes, the data is relevant because the initial question is asking about top Australain news over the last decade, and we have about 17 years data ,
# that 10 last years which is 2009 to 2019 can answer our question, and also we have headlines of articles which lead us to gain the top news.

# %% [markdown]
# # We are dealing with **unstructure** data. ???

# %% [markdown]
# # 3. Data Cleaning

# %%
len(news['headline_text'].unique())
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1186018 entries, 0 to 1186017
# Data columns (total 2 columns):
# publish_date     1186018 non-null int64
# headline_text    1186018 non-null object
# dtypes: int64(1), object(1)
# memory usage: 18.1+ MB

# %%
# demonstrate numbers of articles in each day
news.publish_date.value_counts()
# Out:
# 20120824    384
# 20130412    383
# 20110222    380
# 20120814    379
# 20130514    378
#            ...
# 20060902     19
# 20150110     19
# 20150118     19
# 20150117     18
# 20170209      1
# Name: publish_date, Length: 6152, dtype: int64

# %% [markdown]
# ### Date Cleaning

# %%
news["year"] = news["publish_date"].astype(str).str[:4].astype(np.int64)
news["month"] = news["publish_date"].astype(str).str[4:6].astype(np.int64)
news.head()
# Out:
#    publish_date                                      headline_text  year  \
# 0      20030219  aba decides against community broadcasting lic...  2003
# 1      20030219     act fire witnesses must be aware of defamation  2003
# 2      20030219     a g calls for infrastructure protection summit  2003
# 3      20030219           air nz staff in aust strike for pay rise  2003
# 4      20030219      air nz strike to affect australian travellers  2003
#
#    month
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %% [markdown]
# **Question**
#
# ???
#
# - In our business concern we are looking for data over decade, so we need data from **2009-2019**
# - As we have all data from 2003 , we need to filter data and just continue our analysis with data over decade which is our business concern.

# %%
# Making new dataset and we are using that so on
news_decade = news[news['year'] >= 2009]
news_decade = pd.DataFrame(news_decade)

# %%
# frequency of articles in whole year in decade
# %matplotlib inline
news_decade.groupby(['year']).size().plot(kind='bar', figsize = (10,5))

# we have more news article at 2013 and then 2012 ,

# %% [markdown]
# ### Text cleaning

# %% [markdown]
# **Question**
#
# What kind of text do we have in headline_text?

# %%
news_decade['headline_text'].head()
# Out:
# 433861    2008 deadliest year for us forces in afghanistan
# 433862                     2008 dubbed wet year for hunter
# 433863          2 israelis injured in danish mall shooting
# 433864           8500 qld homes without power after storms
# 433865                     about 60 killed in bankgok fire
# Name: headline_text, dtype: object

# %% [markdown]
# First sight:
#
# - It seems that we have text in headline_text column all in lowercase.
# - There is no punctuations in our text.
# - If we have a big data it was safer to check punctuation and capital and lower cases cause it would be imposible to look at all data.
# - There are words which are not important to our analysis, I need to remove them, I will do that later on.

# %% [markdown]
# **Question**

# %%
news_decade["headline_len"] = news_decade["headline_text"].str.len()
news_decade
# Out:
#          publish_date                                      headline_text  \
# 433861       20090101   2008 deadliest year for us forces in afghanistan
# 433862       20090101                    2008 dubbed wet year for hunter
# 433863       20090101         2 israelis injured in danish mall shooting
# 433864       20090101          8500 qld homes without power after storms
# 433865       20090101                    about 60 killed in bankgok fire
# ...               ...                                                ...
# 1186013      20191231  vision of flames approaching corryong in victoria
# 1186014      20191231  wa police and government backflip on drug amne...
# 1186015      20191231  we have fears for their safety: victorian premier
# 1186016      20191231                              when do the 20s start
# 1186017      20191231  yarraville shooting woman dead man critically ...
#
#          year  month  headline_len
# 433861   2009      1            48
# 433862   2009      1            31
# 433863   2009      1            42
# 433864   2009      1            41
# 433865   2009      1            31
# ...       ...    ...           ...
# 1186013  2019     12            49
# 1186014  2019     12            54
# 1186015  2019     12            49
# 1186016  2019     12            21
# 1186017  2019     12            53
#
# [752157 rows x 5 columns]

# %% [markdown]
# Let's calculate how many words are in our dataset and put in a new column. named **word_count**.
#
# Then, we can check if there is any empty headline.

# %%
# How many words in each headline and what is the mean of numbers of words
# Add a column to datset
news_decade['word_count'] = news_decade['headline_text'].apply(lambda x: len(x.split()))
news_decade[news_decade['word_count'] == 0 ].count()[0]
# Out:
# 0

# %%
news_decade
# Out:
#          publish_date                                      headline_text  \
# 433861       20090101   2008 deadliest year for us forces in afghanistan
# 433862       20090101                    2008 dubbed wet year for hunter
# 433863       20090101         2 israelis injured in danish mall shooting
# 433864       20090101          8500 qld homes without power after storms
# 433865       20090101                    about 60 killed in bankgok fire
# ...               ...                                                ...
# 1186013      20191231  vision of flames approaching corryong in victoria
# 1186014      20191231  wa police and government backflip on drug amne...
# 1186015      20191231  we have fears for their safety: victorian premier
# 1186016      20191231                              when do the 20s start
# 1186017      20191231  yarraville shooting woman dead man critically ...
#
#          year  month  headline_len  word_count  headline_str  uniq_wds
# 433861   2009      1            48           8          True      True
# 433862   2009      1            31           6          True      True
# 433863   2009      1            42           7          True      True
# 433864   2009      1            41           7          True      True
# 433865   2009      1            31           6          True      True
# ...       ...    ...           ...         ...           ...       ...
# 1186013  2019     12            49           7          True      True
# 1186014  2019     12            54           9          True      True
# 1186015  2019     12            49           8          True      True
# 1186016  2019     12            21           5          True      True
# 1186017  2019     12            53           7          True      True
#
# [752157 rows x 8 columns]

# %% [markdown]
# Next step, take a look for the longest and shortest articles in our data set.

# %%
news_decade['word_count'].max()
# Out:
# 15

# %%
news_decade['word_count'].min()
# Out:
# 1

# %% [markdown]
#  We counted all words from headlines included the most common words in English too, though, we don’t want to need *all* words in our count.
#     There are lots of common English words like "or", "and", "we", etc. They are called **stopwords** in text processing. We have to use module stopwords from nltk.corpus. It imported at the beginning of the projct.

# %%
nltk.download('stopwords') # need to download this package 
stopwords.words('english') # show common words in English
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# let's remove commom english words from our count.
#
# To do this we are going to use Python **Counter** which is an unordered collection where elements are stored as Dictionary key and thier count as Dictionary value.
#
# We are used Counter to count each words of our headlines. Then we are able to use **most_common** method to fid out which words were common over last decade which is answering one of the question in business concern.

# %%
from collections import Counter
wd_counts = Counter()
for i, row in news_decade.iterrows():
    wd_counts.update(row['headline_text'].split())

# %%
To remove most common English words I

# %%
from copy import deepcopy

#Add a comment here about why you are creating keys
updated = wd_counts.copy()

keys = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves','he' ,'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it',
 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that',  'these','those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have',
 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between',
  'into','through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when',
 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
 'just', 'don',  'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren',  'doesn',   'ma',  'first', 'one', 'two','back','man','day', 'new', 'won','says' ]

list(map(updated.pop, keys))

updated
# Out:
# Counter({'2008': 58,
#          'deadliest': 35,
#          'year': 4981,
#          'us': 9213,
#          'forces': 1069,
#          'afghanistan': 865,
#          'dubbed': 29,
#          'wet': 642,
#          'hunter': 2427,
#          '2': 1384,
#          'israelis': 23,
#          'injured': 2383,
#          'danish': 76,
#          'mall': 261,
#          'shooting': 2694,
#          '8500': 1,
#          'qld': 6881,
#          'homes': 1267,
#          'without': 930,
#          'power': 3961,
#          'storms': 727,
#          '60': 287,
#          'killed': 4354,
#          'bankgok': 2,
#          'fire': 9530,
#          'act': 3747,
#          'govt': 3185,
#          'bodies': 484,
#          'forced': 805,
#          'comply': 18,
#          'human': 1132,
#          'rights': 1190,
#          'property': 1154,
#          'prices': 2385,
#          'growth': 1277,
#          'predicted': 283,
#          'self': 523,
#          'seen': 416,
#          'cost': 1661,
#          'cutting': 300,
#          'exercise': 243,
#          'alice': 1363,
#          'police': 21167,
#          'arrest': 1350,
#          '83': 48,
#          'celebrations': 293,
#          'anger': 678,
#          'grows': 320,
#          'falls': 1496,
#          'festival': 1912,
#          'breath': 103,
#          'tests': 839,
#          'archives': 77,
#          'reveal': 747,
#          'lessons': 259,
#          'swan': 824,
#          'arrests': 620,
#          'shots': 316,
#          'fired': 473,
#          'assaults': 390,
#          'sydney': 8197,
#          'nye': 159,
#          'australia': 11456,
#          'ups': 233,
#          'gaza': 477,
#          'aid': 1376,
#          '5m': 93,
#          'welcomes': 1041,
#          '2009': 124,
#          'bad': 798,
#          'start': 1881,
#          'vic': 1589,
#          'roads': 1029,
#          'bangladesh': 595,
#          'salvages': 13,
#          'honour': 570,
#          'test': 3680,
#          'defeat': 545,
#          'bendigo': 993,
#          'water': 6421,
#          'restrictions': 526,
#          'ease': 605,
#          'benitez': 30,
#          'backs': 2259,
#          'gerrard': 78,
#          'lead': 2454,
#          'cup': 4991,
#          'tie': 143,
#          'bjork': 3,
#          'turns': 936,
#          'venture': 134,
#          'capitalist': 6,
#          'bligh': 533,
#          'urges': 1966,
#          'residents': 3477,
#          'help': 4048,
#          'boost': 3272,
#          'tourism': 1954,
#          'boat': 1884,
#          'crash': 7029,
#          'passengers': 405,
#          'lucky': 369,
#          'emergency': 1987,
#          'worker': 1271,
#          'bolt': 230,
#          'sets': 913,
#          'sights': 211,
#          'lowering': 30,
#          'records': 759,
#          'bombs': 205,
#          'kill': 1065,
#          'six': 1391,
#          'northern': 2048,
#          'iraq': 900,
#          'bonus': 150,
#          'wasted': 57,
#          'boy': 1692,
#          'critical': 1022,
#          'stabbing': 1757,
#          'brisbane': 3885,
#          'welcome': 1025,
#          'british': 1222,
#          'marine': 783,
#          'bush': 974,
#          'receives': 384,
#          'civilian': 97,
#          'casualty': 42,
#          'assurances': 108,
#          'byron': 320,
#          'probe': 2738,
#          'french': 1238,
#          'tourists': 694,
#          'death': 7535,
#          'accident': 1336,
#          'calls': 5448,
#          'sa': 6269,
#          'bag': 285,
#          'ban': 3544,
#          'go': 2777,
#          'national': 4926,
#          'chef': 169,
#          'charged': 7098,
#          'meat': 744,
#          'cleaver': 42,
#          'attack': 4850,
#          'chinas': 459,
#          'hu': 87,
#          'military': 1169,
#          'exchanges': 11,
#          'taiwan': 296,
#          'china': 5114,
#          'vietnam': 512,
#          'resolve': 131,
#          'border': 793,
#          'dispute': 1063,
#          'commission': 2167,
#          'drop': 1014,
#          'gold': 4296,
#          'coast': 6178,
#          'condobolin': 30,
#          'woman': 6308,
#          'awarded': 425,
#          'medical': 1000,
#          'scholarship': 77,
#          'crew': 347,
#          'error': 226,
#          'caused': 302,
#          'fatal': 2857,
#          'everest': 148,
#          'plane': 1847,
#          'crippling': 30,
#          'budgets': 68,
#          'keep': 1691,
#          'aussies': 1076,
#          'away': 1119,
#          'americas': 138,
#          'crocs': 183,
#          'blaze': 2040,
#          'hawks': 667,
#          'light': 1814,
#          'years': 4019,
#          'eve': 323,
#          'dairy': 1964,
#          'farmers': 4464,
#          'union': 2918,
#          'concerned': 783,
#          'milk': 982,
#          'dhoni': 57,
#          'protected': 168,
#          '45': 95,
#          'commandos': 20,
#          'threat': 2235,
#          'digital': 502,
#          'tvs': 23,
#          'debuts': 45,
#          'disability': 738,
#          'service': 2665,
#          'extra': 733,
#          'funding': 4321,
#          'dog': 2042,
#          'walker': 286,
#          'stumbles': 44,
#          'mummified': 16,
#          'head': 1912,
#          'dr': 809,
#          'congo': 113,
#          'crisis': 1788,
#          'ignored': 199,
#          'driver': 3097,
#          'dozens': 653,
#          'train': 2114,
#          'hits': 2442,
#          'truck': 1702,
#          'economy': 1169,
#          'terrorism': 631,
#          'concerns': 2530,
#          'fraser': 685,
#          'eta': 8,
#          'attacks': 1865,
#          'basque': 15,
#          'tv': 885,
#          'station': 2468,
#          'europe': 508,
#          'marks': 479,
#          'sees': 732,
#          'eu': 537,
#          'headed': 185,
#          'eurosceptic': 4,
#          'czechs': 28,
#          'everinghams': 2,
#          'cabinet': 815,
#          'papers': 176,
#          'fashions': 14,
#          'ex': 1667,
#          'mafia': 86,
#          'boss': 1723,
#          'tennis': 456,
#          'top': 3793,
#          'target': 1309,
#          'fixers': 12,
#          'warned': 1442,
#          'next': 1357,
#          'generation': 304,
#          'locust': 218,
#          'plague': 175,
#          'fireworks': 313,
#          'suspected': 975,
#          'deadly': 986,
#          'thai': 936,
#          'nightclub': 327,
#          'wow': 33,
#          'crowds': 374,
#          'cut': 2676,
#          'dead': 3983,
#          'bangkok': 197,
#          'nsw': 9773,
#          'baby': 1999,
#          'born': 256,
#          'lismore': 161,
#          'flatley': 1,
#          'cured': 12,
#          'irish': 312,
#          'energy': 1816,
#          'healer': 11,
#          'flying': 670,
#          'scotsman': 3,
#          'hoy': 13,
#          'knighted': 7,
#          'food': 2413,
#          'safety': 2550,
#          'problem': 785,
#          'wagga': 414,
#          'mayor': 2413,
#          'former': 4058,
#          'spy': 385,
#          'found': 5857,
#          'guilty': 3734,
#          'indonesian': 1049,
#          'toll': 1195,
#          '400': 136,
#          'recessions': 3,
#          'dampen': 56,
#          'gippsland': 794,
#          'risk': 2027,
#          'goldfields': 398,
#          'truckies': 95,
#          'coronial': 201,
#          'inquest': 1919,
#          'take': 3268,
#          'roll': 521,
#          'charges': 3521,
#          '09': 49,
#          'green': 2487,
#          'bags': 182,
#          'also': 72,
#          'polluting': 35,
#          'warn': 716,
#          'retailers': 298,
#          'gun': 1190,
#          'handcuffs': 9,
#          'capsicum': 78,
#          'spray': 209,
#          'stolen': 1305,
#          'car': 5778,
#          'harbour': 842,
#          'bridge': 1131,
#          'e': 374,
#          'tag': 120,
#          'alternatives': 64,
#          'offered': 481,
#          'hasina': 2,
#          'promises': 1128,
#          'political': 1447,
#          'culture': 595,
#          'heart': 911,
#          'doctors': 1227,
#          'tell': 336,
#          'potential': 588,
#          'donors': 84,
#          'haydens': 3,
#          'trial': 4497,
#          'media': 3012,
#          'un': 1864,
#          'australian': 10169,
#          'symonds': 64,
#          'hobart': 2065,
#          'holiday': 558,
#          'road': 3935,
#          '50': 697,
#          'mining': 3404,
#          'sector': 820,
#          'surges': 201,
#          'ahead': 2764,
#          'global': 1194,
#          'praise': 250,
#          'revellers': 94,
#          'behaviour': 396,
#          'illawarra': 333,
#          'local': 2423,
#          'scam': 491,
#          'inquiry': 3114,
#          'rail': 2292,
#          'fatality': 169,
#          'israeli': 409,
#          'troops': 680,
#          'enter': 218,
#          'hamas': 131,
#          'israel': 847,
#          'moves': 1154,
#          'closer': 635,
#          'invasion': 550,
#          'rejects': 1609,
#          'truce': 104,
#          'lake': 1390,
#          'macquarie': 662,
#          'presence': 98,
#          'strong': 1254,
#          'pittwater': 23,
#          'coffs': 628,
#          'large': 418,
#          'shark': 1343,
#          'spotted': 242,
#          'fremantle': 473,
#          'ledger': 37,
#          'voted': 99,
#          '2008s': 2,
#          'biggest': 671,
#          'movie': 285,
#          'story': 872,
#          'locals': 607,
#          'battle': 1821,
#          'teen': 2395,
#          'drinking': 437,
#          'campaign': 2397,
#          'london': 977,
#          'bombing': 495,
#          'survivor': 414,
#          'honoured': 450,
#          'queens': 325,
#          'list': 822,
#          'camping': 120,
#          'ground': 584,
#          'mandatory': 269,
#          'abuse': 2778,
#          'reporting': 302,
#          'comes': 604,
#          'force': 1494,
#          'wa': 8211,
#          'dies': 4966,
#          'bombo': 3,
#          'beach': 1735,
#          'near': 2665,
#          'kiama': 42,
#          'faces': 2628,
#          'court': 10768,
#          'armed': 923,
#          'robberies': 222,
#          'fined': 1569,
#          'flare': 108,
#          'hospitalised': 302,
#          'robbery': 907,
#          'stabbed': 777,
#          'forster': 59,
#          'stable': 168,
#          'eungai': 1,
#          'creek': 1171,
#          'mariners': 441,
#          'end': 2884,
#          'pile': 112,
#          'markets': 2611,
#          'horror': 352,
#          'positive': 568,
#          'note': 210,
#          'tipped': 824,
#          'bounce': 341,
#          'massive': 567,
#          'crowd': 479,
#          'matt': 741,
#          'dillon': 43,
#          'arrested': 2942,
#          'speeding': 325,
#          'minister': 4382,
#          'orders': 550,
#          'minor': 204,
#          'croc': 547,
#          'cull': 383,
#          'monaro': 270,
#          'christmas': 2048,
#          'trading': 660,
#          'unaffected': 19,
#          'credit': 521,
#          'pipe': 151,
#          'network': 602,
#          'curb': 187,
#          'hinze': 8,
#          'waste': 1112,
#          'sheep': 1104,
#          'tagging': 43,
#          'laws': 2678,
#          'begin': 764,
#          'regulations': 182,
#          'today': 344,
#          'grenade': 62,
#          'wounds': 124,
#          '22': 585,
#          'philippines': 798,
#          'across': 1075,
#          'asia': 700,
#          'york': 737,
#          'cheer': 79,
#          'chilly': 23,
#          'yorkers': 12,
#          'shiver': 7,
#          'honking': 2,
#          'campaigners': 91,
#          'delhis': 13,
#          'beep': 2,
#          'boys': 743,
#          'assistant': 146,
#          'commissioner': 852,
#          'catherine': 139,
#          'burn': 454,
#          'fees': 469,
#          'fares': 67,
#          'payroll': 139,
#          'tax': 3589,
#          'lowest': 121,
#          'since': 595,
#          '1944': 3,
#          'reveller': 5,
#          'officer': 1533,
#          'orange': 432,
#          'museum': 654,
#          'collections': 10,
#          'set': 4340,
#          'improve': 608,
#          'outcry': 59,
#          'pensioners': 96,
#          'red': 1796,
#          'fine': 674,
#          'withdrawn': 91,
#          'pakistan': 1878,
#          'khyber': 6,
#          'pass': 382,
#          'militants': 271,
#          'panthers': 368,
#          'ordered': 481,
#          'pay': 2972,
#          '114k': 1,
#          'fall': 1927,
#          'plastic': 361,
#          'scheme': 1829,
#          'bagged': 7,
#          'nt': 4369,
#          'investigate': 1397,
#          'driveway': 115,
#          'body': 2481,
#          'well': 718,
#          'behaved': 30,
#          'glenelg': 74,
#          'assault': 3020,
#          'bid': 2511,
#          'firecrackers': 3,
#          'children': 2442,
#          'poor': 644,
#          'succession': 92,
#          'planning': 1202,
#          'possum': 80,
#          'highways': 30,
#          'recommended': 89,
#          'south': 6233,
#          'west': 4074,
#          'plays': 402,
#          'revealed': 625,
#          '1978': 7,
#          'minutes': 202,
#          'pregnant': 350,
#          'family': 3625,
#          'flees': 112,
#          'premier': 2458,
#          'mike': 574,
#          'rann': 179,
#          'plans': 3382,
#          'tougher': 386,
#          'rules': 1579,
#          'talks': 3876,
#          'months': 760,
#          'frome': 33,
#          'dumps': 196,
#          'rebate': 231,
#          'quake': 842,
#          'indonesias': 154,
#          'maluku': 1,
#          'geophysics': 4,
#          'agency': 356,
#          'racegoers': 7,
#          'face': 3818,
#          'scorching': 32,
#          'perth': 4240,
#          'weather': 3279,
#          'voters': 550,
#          'taken': 514,
#          'granted': 633,
#          'realistic': 30,
#          'goals': 159,
#          'key': 1291,
#          'keeping': 364,
#          'ny': 152,
#          'resolutions': 18,
#          'ama': 316,
#          'recession': 235,
#          'reclusive': 4,
#          'writer': 123,
#          'jd': 6,
#          'salinger': 6,
#          '90': 208,
#          'rescued': 1060,
#          'music': 1063,
#          'teens': 954,
#          'sorry': 416,
#          'researchers': 706,
#          'develop': 220,
#          'electronic': 109,
#          'cattle': 2725,
#          'tags': 44,
#          'party': 2301,
#          'hard': 651,
#          'riverina': 416,
#          'captures': 242,
#          'domestic': 1345,
#          'market': 4985,
#          'rspca': 409,
#          'raids': 596,
#          'already': 153,
#          'animal': 887,
#          'russia': 1263,
#          'cuts': 3099,
#          'ukraine': 544,
#          'gas': 2481,
#          'supplies': 241,
#          'shut': 468,
#          'ukraines': 22,
#          'supply': 743,
#          'sarkozy': 54,
#          'middle': 379,
#          'east': 2309,
#          'monday': 1672,
#          'scores': 471,
#          'secret': 606,
#          'frasers': 10,
#          'woes': 803,
#          'sex': 4595,
#          'fans': 899,
#          'italy': 445,
#          'doesnt': 344,
#          'sell': 752,
#          'norway': 141,
#          'cracks': 235,
#          'prostitution': 96,
#          'sightings': 102,
#          'frequent': 20,
#          'adelaides': 207,
#          'gulf': 406,
#          'siege': 674,
#          'accused': 5613,
#          'remanded': 246,
#          'custody': 821,
#          'korea': 1912,
#          'fascist': 9,
#          'treacherous': 11,
#          'north': 5761,
#          'smith': 1772,
#          'miss': 1082,
#          'series': 948,
#          'smoking': 491,
#          'lowers': 56,
#          'city': 2518,
#          'build': 535,
#          'bridges': 75,
#          'drug': 3861,
#          'trafficker': 56,
#          'collapses': 246,
#          'stuarts': 13,
#          'point': 1093,
#          'undergoes': 67,
#          'knee': 230,
#          'surgery': 859,
#          'taliban': 478,
#          'kills': 1399,
#          '20': 1173,
#          'afghan': 1078,
#          'tas': 1952,
#          'beats': 939,
#          'bulls': 793,
#          'twenty20': 261,
#          'oppn': 203,
#          'shack': 41,
#          'owner': 693,
#          'compensation': 803,
#          'allegedly': 763,
#          'gang': 570,
#          'raped': 163,
#          'double': 1277,
#          'assaulting': 340,
#          'territorians': 63,
#          'unlikely': 525,
#          'donate': 75,
#          'organs': 26,
#          '100': 884,
#          'brawl': 819,
#          'world': 6384,
#          'celebrates': 808,
#          'three': 3263,
#          'hurt': 1002,
#          'toddler': 674,
#          'drowns': 284,
#          'dam': 1032,
#          'gin': 89,
#          'tough': 1016,
#          'talking': 302,
#          'putin': 454,
#          'gives': 1331,
#          'ultimatum': 78,
#          'tsonga': 111,
#          'dominate': 272,
#          'djokovic': 512,
#          'hume': 144,
#          'highway': 1591,
#          'wyong': 61,
#          'smash': 430,
#          'underdone': 7,
#          'ready': 1620,
#          'hopman': 127,
#          'meeting': 1448,
#          'ends': 1172,
#          'resolution': 148,
#          'hands': 522,
#          'saddams': 6,
#          'baghdad': 139,
#          'palace': 140,
#          'control': 1460,
#          'bagdad': 9,
#          'zone': 724,
#          'victoria': 2482,
#          'wollongong': 335,
#          'social': 1237,
#          'plan': 5794,
#          'underway': 908,
#          'council': 8335,
#          'unit': 709,
#          'seriously': 255,
#          'bribie': 28,
#          'young': 2454,
#          'drivers': 1370,
#          '12': 1125,
#          'mexico': 504,
#          'war': 2582,
#          'rampage': 162,
#          '14': 773,
#          'locked': 255,
#          'warrnambool': 223,
#          'documents': 448,
#          'released': 1418,
#          '30000': 45,
#          'zimbabweans': 10,
#          'cholera': 67,
#          '3': 1022,
#          'india': 2105,
#          'captain': 710,
#          '59': 37,
#          'busted': 66,
#          'drugs': 1397,
#          'sydneys': 337,
#          'field': 599,
#          '73yr': 1,
#          'old': 1928,
#          'attacked': 547,
#          'mayfield': 70,
#          'cbd': 751,
#          'considers': 1124,
#          'republic': 116,
#          'referendum': 337,
#          'herring': 16,
#          'adelaide': 4493,
#          'runner': 167,
#          'flu': 1298,
#          'win': 5406,
#          'burnie': 154,
#          'gift': 200,
#          'use': 1637,
#          'sharply': 71,
#          'air': 1902,
#          'strike': 1981,
#          'leader': 1869,
#          'alcohol': 1118,
#          'related': 276,
#          'deaths': 1481,
#          'anti': 2032,
#          'apartheid': 37,
#          'campaigner': 130,
#          'suzman': 3,
#          'aged': 1162,
#          '91': 50,
#          'report': 5816,
#          'resident': 286,
#          'evacuated': 445,
#          'home': 5516,
#          'arson': 645,
#          'charge': 1962,
#          'northfield': 2,
#          'fires': 1596,
#          'board': 1001,
#          'mother': 1450,
#          'birth': 370,
#          'canada': 416,
#          'club': 1754,
#          'scrutiny': 357,
#          'barassi': 15,
#          'bashed': 351,
#          'coming': 432,
#          'womans': 443,
#          'rescue': 1404,
#          'bega': 321,
#          'mp': 3465,
#          'coastal': 316,
#          'patrol': 201,
#          'ben': 889,
#          'knight': 174,
#          'updates': 474,
#          'radio': 532,
#          'situation': 160,
#          'camp': 851,
#          'site': 1547,
#          'naked': 163,
#          'bollinger': 72,
#          'gets': 3307,
#          'nod': 402,
#          'third': 1454,
#          'bravery': 182,
#          'award': 1121,
#          'saving': 452,
#          'bruce': 426,
#          'hwy': 213,
#          'closed': 653,
#          'burma': 304,
#          'releases': 560,
#          '19': 540,
#          'korean': 674,
#          'refugees': 726,
#          'call': 5808,
#          'bequest': 18,
#          'spent': 172,
#          'historic': 909,
#          'church': 1071,
#          'councils': 1221,
#          'given': 990,
#          'canberra': 4552,
#          'despite': 1923,
#          'downturn': 315,
#          'melbourne': 5063,
#          'chinese': 2302,
#          'firms': 222,
#          'send': 430,
#          'scandal': 777,
#          'sms': 45,
#          'apology': 456,
#          'chocolate': 130,
#          'factory': 729,
#          'blacks': 403,
#          '35000': 10,
#          'clarke': 999,
#          'replaces': 115,
#          'hussey': 210,
#          'icc': 247,
#          '10': 1578,
#          'cloke': 29,
#          'fight': 3452,
#          'dangerous': 620,
#          'email': 264,
#          'missing': 4645,
#          'contradictory': 7,
#          'australians': 1460,
#          'think': 372,
#          'ok': 133,
#          'speed': 1025,
#          'coral': 330,
#          'declines': 81,
#          'great': 1545,
#          'barrier': 609,
#          'reef': 892,
#          'admits': 1163,
#          'workers': 3509,
#          'wendouree': 15,
#          'hopes': 1795,
#          'state': 3690,
#          'battery': 145,
#          'reminds': 33,
#          '4wd': 167,
#          'owners': 843,
#          'permit': 146,
#          'policy': 1699,
#          'seeks': 1374,
#          'federal': 3261,
#          'sporting': 218,
#          'tackles': 183,
#          'inman': 5,
#          'river': 2513,
#          'stench': 28,
#          'cowboy': 45,
#          'wingham': 18,
#          'rodeo': 235,
#          'cuba': 143,
#          'revolution': 176,
#          'anniversary': 727,
#          'marked': 53,
#          '50th': 70,
#          'giant': 726,
#          'may': 4685,
#          'costs': 1021,
#          'amid': 1650,
#          'economic': 1209,
#          'debts': 86,
#          'piling': 5,
#          'decomposing': 12,
#          'dirt': 145,
#          'detectives': 105,
#          'release': 1305,
#          'name': 915,
#          'died': 464,
#          'dietitian': 4,
#          'obesity': 210,
#          'impacting': 68,
#          'industry': 3526,
#          'david': 2203,
#          'coward': 34,
#          'speaks': 3102,
#          'weber': 10,
#          'investigation': 1552,
#          'continues': 2367,
#          'ecb': 55,
#          'meet': 1619,
#          'pietersen': 128,
#          'moores': 17,
#          'rift': 88,
#          'enthusiastic': 10,
#          'divers': 219,
#          'greet': 35,
#          'icy': 56,
#          'dip': 129,
#          'epa': 427,
#          'stands': 460,
#          'handling': 275,
#          'methane': 62,
#          'leak': 603,
#          'organisers': 190,
#          'disappointed': 341,
#          'testing': 688,
#          'families': 1013,
#          'relieved': 131,
#          'men': 2111,
#          'crossing': 407,
#          'worst': 636,
#          'fesa': 44,
#          'warns': 2139,
#          'people': 2990,
#          'high': 4145,
#          'alert': 851,
#          'crews': 890,
#          'clean': 1253,
#          'purnim': 2,
#          'hay': 411,
#          'destroys': 390,
#          'recounts': 113,
#          'five': 2030,
#          'kempsey': 147,
#          'culburra': 3,
#          'rollover': 167,
#          'forbes': 133,
#          'hang': 170,
#          'gliding': 25,
#          'competition': 595,
#          'enticing': 6,
#          'forests': 169,
#          'enforcing': 13,
#          'gaffney': 7,
#          'undecided': 81,
#          'politics': 1067,
#          'garrett': 251,
#          'make': 2342,
#          'pulp': 187,
#          'mill': 733,
#          'decision': 2111,
#          'ghana': 50,
#          'ruling': 561,
#          'vote': 2088,
#          'delay': 1012,
#          'giteau': 88,
#          'stay': 1373,
#          'gitmo': 29,
#          'detainees': 207,
#          'arent': 81,
#          'newcastle': 2011,
#          'exit': 336,
#          'financial': 1172,
#          'fails': 888,
#          'sink': 168,
#          'bollywood': 68,
#          'beat': 1775,
#          'festive': 48,
#          'season': 2843,
#          'visitors': 256,
#          'urged': 3012,
#          'solvents': 2,
#          'allays': 4,
#          'guantanamo': 99,
#          'resettlement': 73,
#          'pledges': 641,
#          '10m': 114,
#          'fix': 830,
#          'crossings': 47,
#          'grass': 341,
#          'tackled': 32,
#          'clare': 93,
#          'accepts': 245,
#          'offer': 1073,
#          'conditions': 962,
#          'declares': 331,
#          'wrath': 28,
#          'leaders': 1362,
#          'hammers': 62,
#          'consider': 784,
#          'offers': 1025,
#          'window': 166,
#          'opens': 1551,
#          'bell': 395,
#          'give': 954,
#          'big': 3818,
#          'kick': 268,
#          'hewitt': 469,
#          'voltage': 9,
#          'line': 1358,
#          'project': 2004,
#          'track': 1492,
#          'hilfenhaus': 48,
#          'unlucky': 27,
#          'tigers': 1575,
#          'coach': 1642,
#          'rises': 1026,
#          '55': 48,
#          'hull': 95,
#          'demand': 1413,
#          'penalty': 523,
#          'drink': 1013,
#          'continue': 1626,
#          'rise': 3590,
#          'clue': 50,
#          'lost': 1070,
#          'antarctic': 327,
#          'counts': 145,
#          'scrapping': 93,
#          ...})

# %%
updated.most_common(20)
# Out:
# [('police', 21167),
#  ('interview', 14183),
#  ('australia', 11456),
#  ('court', 10768),
#  ('australian', 10169),
#  ('nsw', 9773),
#  ('fire', 9530),
#  ('us', 9213),
#  ('council', 8335),
#  ('wa', 8211),
#  ('sydney', 8197),
#  ('government', 8024),
#  ('death', 7535),
#  ('charged', 7098),
#  ('crash', 7029),
#  ('rural', 6969),
#  ('murder', 6884),
#  ('qld', 6881),
#  ('health', 6521),
#  ('water', 6421)]

# %% [markdown]
# result :
# - The word **Police**  and **Court** ,**Death** , **Murder** , **Charged**  are the most common words that is being use during decade. They are quite related in context.
#
# - The words **Death** and **Murder** , ****are also in the list of 20 top news.

# %%
Next:
    
    - compare data for half a year and check the frequency

# %%
In 20 top words there nothing about climate change but we know in national conversation these last 2 years, we had lots of news about all of proteted around the world.. 
Also about **refugees** , but there is nothing particulary clear about it.

In this point we are going to analyse more deeply about refugee in australia and

# %%
def find_cc_wds(content, cc_wds=['climate change','global warming', 'extreme weather', 'greenhouse gas'
                                 'clean energy', 'clean tech', 'renewable energy']
):
    found = False
    for w in cc_wds:
        if w in content:
            found = True
            break

    if not found:
        disj = re.compile(r'(chang\w+\W+(?:\w+\W+){1,5}?climate) | (climate\W+(?:\w+\W+){1,5}?chang)')
        if disj.match(content):
            found = True
    return found

# %%
articles['cc_wds'] = articles['tokenized'].apply(find_cc_wds)
articles['cc_wds'].head()

# %%
def clean_text(article):
    clean1 = re.sub(r'['+string.punctuation + '’—”'+']', "", article.lower())
    return re.sub(r'\W+', ' ', clean1)

# %% [markdown]
# # 4. Analysing/visualisation

# %%
# add a map of australia included top news words

# %%
# how many articles per year

news.groupby('year').count()

# how many articles per day
news.groupby('publish_date').count()

# %% [markdown]
# # 5.Insights

# %%
# !pip install nltk
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting nltk
#   Downloading nltk-3.5.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 11.9 MB/s eta 0:00:01
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from nltk) (7.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.7/site-packages (from nltk) (0.14.1)
# Collecting regex
#   Downloading regex-2020.4.4-cp37-cp37m-manylinux2010_x86_64.whl (679 kB)
#      |████████████████████████████████| 679 kB 40.3 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from nltk) (4.42.0)
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434672 sha256=fdcb2f656c23b7af11931139d5f6a3339ec59e58518e4fb8903ce8c64073d32a
#   Stored in directory: /home/jovyan/.cache/pip/wheels/45/6c/46/a1865e7ba706b3817f5d1b2ff7ce8996aabdd0d03d47ba0266
# Successfully built nltk
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.5 regex-2020.4.4

# %%
#Loading NLTK
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

tokenized_text=sent_tokenize(news['headline_text'])
print(tokenized_text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-0a1465acabff> in <module>
#       1 from nltk.tokenize import sent_tokenize
#       2
# ----> 3 tokenized_text=sent_tokenize(news['headline_text'])
#       4 print(tokenized_text)
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load("tokenizers/punkt/{0}.pickle".format(language))
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1270         Given a text, returns a list of the sentences in that text.
#    1271         """
# -> 1272         return list(self.sentences_from_text(text, realign_boundaries))
#    1273
#    1274     def debug_decisions(self, text):
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1324         follows the period.
#    1325         """
# -> 1326         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1327
#    1328     def _slices_from_text(self, text):
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1314         if realign_boundaries:
#    1315             slices = self._realign_boundaries(text, slices)
# -> 1316         for sl in slices:
#    1317             yield (sl.start, sl.stop)
#    1318
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1355         """
#    1356         realign = 0
# -> 1357         for sl1, sl2 in _pair_iter(slices):
#    1358             sl1 = slice(sl1.start + realign, sl1.stop)
#    1359             if not sl2:
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     312     it = iter(it)
#     313     try:
# --> 314         prev = next(it)
#     315     except StopIteration:
#     316         return
#
# /opt/conda/lib/python3.7/site-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1328     def _slices_from_text(self, text):
#    1329         last_break = 0
# -> 1330         for match in self._lang_vars.period_context_re().finditer(text):
#    1331             context = match.group() + match.group("after_tok")
#    1332             if self.text_contains_sentbreak(context):
#
# TypeError: expected string or bytes-like object
